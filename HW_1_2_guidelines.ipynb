# %% [markdown]
# # HW 1 and 2 Guidelines

# %% [markdown]
# Task 1. Bifurcation, logistic maps
# ------
#
# Video about logistic mapping:
#
# https://www.youtube.com/watch?v=ovJcsL7vyrk
#
# Provided:
#
# $r$ - constant value (r<4?)
#
# $x_0 \in [0,1]$
#
# Map:
#
# $x_{n+1} = r x_n(1-x_n)$
#
# Problem:
#
# 1. For different values $x_0$ and $r$ plot an evolution $x$, play with the values, observe the difference in the dynamics.
# 2. Create `linspace` of $r$ values, for each $r$ and chosen $x_0$ values create an evolution, save last $m$ values of $x$ after first $n$ iterations, for example, last 50 values after first 100 initial iterations.
# 3. Plot the bifurcation diagram
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/LogisticMap_BifurcationDiagram.png/1600px-LogisticMap_BifurcationDiagram.png)

# %%
def logistic_map_step(x, r):
    return r * x * (1 - x)

'''
your implementation
'''
'''
During the task try not to use built-in list structure with append method - it is ineffective resource-wise.
Try using numpy array.
If you are interested, you may try to make a comparison between list and array implementations to see the difference.
'''
# Out:
# '\nyour implementation\n'

# %% [markdown]
# Task 2. Julia fractal
# -------
#
# Very similar, but in complex numbers.
#
# $z_0 \in \mathbb{C}$
#
# $C \in \mathbb{C}$
#
# $z_{n+1} = z_n^2 + C$
#
# Step-by-step guide:
#
# 1. Build the visualization, observe $z$ dynamics for any chosen $C$.
# 2. By changing $z_0$ see the difference in dynamics.
# 3. Create 2D matrix which displays $z_0$ values for Re and Im both in range -2, 2. For each matrix point (it corresponds to some value $z_0 = Re + Im$) create a dynamics for 'max_iter' number of times. If $z$ absolute value on any step becomes larger than 2 (you can modulate it) - return the iteration at which it happened. If not - return 'max_iter'
# 4. Plot the fractal
#
# Problem:
#
# * For $c=e^{ia}$, where `a = range(0, 2pi)` build fractal dynamic change animation:
#
# https://stackoverflow.com/questions/753190/programmatically-generate-video-or-animated-gif-in-python

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.eye(100, dtype=np.float32)

# %%
plt.imshow(A)

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
C = 0.1+0.1j

z = -0.5 + 1j

for n in range(100):
    z = z**2 + C
    print(z, np.sqrt(z*z.conjugate()))


#  z = 0 + 0j   ----> 100
#  z = -1 + 0j  -----> 3
#  z = -0.5 +0j ----> 100
#  z = -0.5 + 1j ----> 4


2 x x x x x x x x x
  x x x x x x x x x
  x x x x x x x x x
Imx x x x x x x x x
  x x x 100 100 x x x x
  x x x x x x x x x
  x x x x x x x x x
-22 x x x x x x x x
 -2     Re(z0)    2
# Out:
#   Cell In[5], line 16
#     2 x x x x x x x x x
#       ^
# SyntaxError: invalid syntax

# %%
A = np.zeros((10,10))

A[5,5]=4
A[5,4]=3
A[4,4]=2
A[1,1]=2

# %%
plt.imshow(A)
